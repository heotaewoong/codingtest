# %%
k=list(map(int,input().split()))

# %%
m = list(map(int, input()))
print(m)

m = list(map(int, input().strip()))
print(m)
# Out:
# [1, 2, 3, 1, 2, 3]
# [5, 3, 4, 5, 3, 4]

# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.12.10 (v3.12.10:0cc81280367, Apr  8 2025, 08:46:59) [Clang 13.0.0 (clang-1300.0.29.30)]
# /usr/local/bin/python3

# %%
k
# Out:
# [123123]

# %%
a=list('adcsad')

# %%
a
# Out:
# ['a', 'd', 'c', 's', 'a', 'd']

# %%
cmd='1 3'.split()

# %%
cmd
# Out:
# ['1', '3']

# %%
cmd1=map(int,cmd)

# %%
print(cmd1)
# Out:
# <map object at 0x10a881030>

# %%
print(-1)
# Out:
# -1

# %%
lst=[1,2,3,4,5,6,7,8,9]

# %%
lst[-2]
# Out:
# 8

# %%
lst=list(range(5))
print(lst)
# Out:
# [0, 1, 2, 3, 4]
